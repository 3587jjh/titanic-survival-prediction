# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn.functional as F
import torch.optim as optim

##################### Data analyzing #####################
df = pd.read_csv('train.csv')

#df_test = pd.read_csv('test.csv')
#print(df.info())
#print(df_test.info())
df['FamilySize'] = df['SibSp'] + df['Parch']
df.drop(['Cabin', 'SibSp', 'Parch'], axis=1, inplace=True)
#print(df.describe())
#print('-'*40)
#print(df.describe(include=['O']))
df.drop(['Name', 'Ticket'], axis=1, inplace=True)

#df['PassengerBand'] = pd.cut(df['PassengerId'], 8)
#print(df[['PassengerBand', 'Survived']].groupby(['PassengerBand'],as_index=False).mean())
#print('-'*40)
#print(df[['Pclass', 'Survived']].groupby(['Pclass'],as_index=False).mean())
#print('-'*40)
#print(df[['Sex', 'Survived']].groupby(['Sex'],as_index=False).mean())
#print('-'*40)
#print(df[['Embarked', 'Survived']].groupby(['Embarked'],as_index=False).mean())
df.drop(['PassengerId'], axis=1, inplace=True)

#df['AgeBand'] = pd.cut(df['Age'], 6)
#print(df[['AgeBand', 'Survived']].groupby(['AgeBand'],as_index=False).mean())
#print('-'*40)
#print(df[['FamilySize', 'Survived']].groupby(['FamilySize'],as_index=False).mean())
#print('-'*40)
#df['FareBand'] = pd.cut(df['Fare'], 50)
#print(df[['FareBand', 'Survived']].groupby(['FareBand'],as_index=False).mean())
#print(df.columns.tolist())

#print(df[['Pclass', 'Age']].groupby(['Pclass'],as_index=False).mean())
#print('-'*40)
#print(df[['Sex', 'Age']].groupby(['Sex'],as_index=False).mean())
#print('-'*40)
#print(df[['Embarked', 'Age']].groupby(['Embarked'],as_index=False).mean())
#print('-'*40)
#print(df[['FamilySize', 'Age']].groupby(['FamilySize'],as_index=False).mean())
#print('-'*40)
#df['FareBand'] = pd.cut(df['Fare'], 50)
#print(df[['FareBand', 'Age']].groupby(['FareBand'],as_index=False).mean())
# Out:
# C:\ProgramData\Anaconda3\envs\pytorch\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
